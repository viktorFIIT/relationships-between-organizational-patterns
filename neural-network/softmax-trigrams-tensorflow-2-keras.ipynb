# %% [markdown]
# **Extracting Relations Between Organizational Patterns with Softmax Regression and Multi-layer Perceptron**
#
# This neural network is designed to classify organizational patterns / pattern languages or organizational pattern sequences. Index of a highest probability prediction as output from a Softmax regression is a pattern sequence classification which you're searching for. Our task here is to find whether we can calculate probabilities and likelihood of the organizational patterns based on the frequencies of the words with which they have been documented with.
#
# This work is a natural continuation of previous research conducted by Waseeb et al. in 'Extracting Relations Between Organizational Patterns Using Association Mining' which you can find here at a following site: http://www2.fiit.stuba.sk/~vranic/pub/ExtractingRelations.pdf.
#
# Dataset we're working with is quite similar to the one published on page 4 in Table 1 entitled as "A matrix sample values for n-gram existence against org. patterns". Difference is that we use TF-IDF frequencies instead of the binary-encoded attributes.
#
# Sample dataset with frequencies of 11 bigrams extracted from textual descriptions of the organizational patterns from http://www.orgpatterns.com/ had been provided in Excel sheet as training set. Validation and test set consist of another previously unseen 7 organizational patterns.
#
# <u>Model output example</u>:
#
# Training dataset consists of frequencies of the trigrams for 18 organizational patterns. Output from this Artificial Neural Network is a vector for a pattern with frequencies from a validation and test dataset with as many components as there are patterns in a training dataset:
#
# for a $pattern_{i}$ = (x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12, x13, x14, x15, x16, x17, x18),
#
# where $x_{i}$ is output from a softmax regression and it's a likelihood of this pattern given observed frequencies of its trigrams. Highest probability from this vector is a classification of the set of the trigram inverse frequencies for a given organizational pattern.
#
# **Main Idea of our Approach**
#
# ![table.drawio-2.png](attachment:table.drawio-2.png)
#
# Validation dataset should be used to optimalize hyperparameters (parameters which are not trained during computation of this ANN) and test dataset shall be used only once.
#
# Please note that prediction is correct if it is consistent with an actual class. Accuracy of the model is one of the metrics used to evaluate this behavior.
#
# Theory behind this can be found in a book Dive into Deep Learning: https://d2l.ai/chapter_linear-networks/softmax-regression.html

# %%
import tensorflow as tf
# keras is facade for tensorflow so we don't have to deal with low-level API
from tensorflow import keras 
from tensorflow.keras.models import Sequential # composite pattern for building neural network
from tensorflow.keras.layers import Dense # input, hidden and output layer
from tensorflow.keras.losses import categorical_crossentropy # loss function
from keras.utils.np_utils import to_categorical # hot-encoding for softmax regression
from tensorflow.keras.optimizers import Adam # optimalizer for neural network

# library for data preprocessing and model evaluation
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

import numpy as np # to handle data compactly
import pandas as pd
import matplotlib.pyplot as plt # plotting library

tf.keras.backend.clear_session()

train_df = pd.read_excel('trigram-pattern-frequencies/trigram-pattern-frequencies-train.xlsx', engine='openpyxl')
val_df = pd.read_excel('trigram-pattern-frequencies/trigram-pattern-frequencies-val.xlsx', engine='openpyxl')
test_df = pd.read_excel('trigram-pattern-frequencies/trigram-pattern-frequencies-test.xlsx', engine='openpyxl')

# %% [markdown]
# **Normalization of organizational patterns trigram frequencies**
#
# Why? Because some of the trigrams (independent variables, attributes X) have higher frequencies than the others. This means they are used more in organizational pattern descriptions than those which are used less. We will normalize these attributes so they contribute equally to the model training process. Normalization is often a must-be to in order to get acceptable results from a machine learning or deep learning models.
#
# Because some of the trigrams are used more often than the others they differ in a (statistical) variance. This means they must be normalized because of this fact too. It's not very good to increase learning rate (as one of the hyperparameters of this neural network) when attributes are not normalized before. This could lead to divergency, when we wouldn't be able to find best parameters in our training process.
#
# Good news is we don't have to weigth our labels (indexes representing organizational patterns) since each class (organizational pattern) is represented only once in our working dataset.

# %%
number_of_patterns = 19

train_scaler = StandardScaler()
train_without_target = train_df.drop(['PatternIndex'], axis=1)
train_without_pattern_name = train_without_target.drop(['OrganizationalPattern'], axis=1)
train_features = train_scaler.fit(train_without_pattern_name.values)

X_train = pd.DataFrame(train_scaler.transform(train_df.iloc[:, 1:-1].values))
y_train = to_categorical(train_df.iloc[:,-1].values, number_of_patterns) # hot-encoding label (pattern index) for softmax regression

val_scaler = StandardScaler()
val_without_target = val_df.drop(['PatternIndex'], axis=1)
val_without_pattern_name = val_without_target.drop(['OrganizationalPattern'], axis=1)
val_features = val_scaler.fit(val_without_pattern_name.values)

X_val = pd.DataFrame(val_scaler.transform(val_df.iloc[:, 1:-1].values))
y_val = to_categorical(val_df.iloc[:,-1].values, number_of_patterns)

test_scaler = StandardScaler()
test_without_target = test_df.drop(['PatternIndex'], axis=1)
test_without_pattern_name = test_without_target.drop(['OrganizationalPattern'], axis=1)
test_features = test_scaler.fit(test_without_pattern_name.values)

X_test = pd.DataFrame(test_scaler.transform(test_df.iloc[:, 1:-1].values))
y_test = to_categorical(test_df.iloc[:,-1].values, number_of_patterns)

# %% [markdown]
# **SoftMax Classification of organizational patterns based on their bigram TF-IDF frequencies**
#
# Activation functions are those components in neural network which are responsible to generate output from a network. Combination of linear functions (layers of the ANN without these functions perform affine transformations only) is still a linear function. That's why we need non-linear activation function. Non-linear activation functions help us to take advantage of the GPU processing capabilities.
#
# We must use non-linear activation functions because if we try to visualize frequencies of the bigrams in 2D space we would not be able to separate these data with linear functions or its lines.
#
# ReLU is one of the standard activation functions used in the neural networks. Softmax is activation function too. Number passed as argument to the constructor of the layer of our Artificial Neural Network is number of perceptrons on this layer. Dropout layer is used as regularization technique to eliminate overfitting of the model on training dataset.
#
# First dense layer is our input layer, or layer to consume our dataset. It has 11 neurons, because we have 11 bigrams in our training dataset. Last layer is output layer of this neural network. All layers between are hidden layers of this neural network. All layers are fully connected layers of this Multi-layer perceptron.
#
# What we're doing here? Well, we go through these steps for 100 epochs:
#
#  1. we pass here our dataset
#  2. we declare Articial Neural Network as Multilayer Perceptron. See https://d2l.ai/chapter_multilayer-perceptrons/index.html
#  3. we declare optimizer which we want to use. It's Adam, best in class: https://arxiv.org/pdf/1412.6980.pdf
#  4. we work with-minibatches. We optimize model parameters passing each 4 rows in our dataset. Batches are passed randomly.
#  5. we perform forward pass through this neural network. That means we actually generate predictions.
#  6. we compute loss and cost from our predictions
#  7. we propagate back this loss through all the layers of ANN. In fact, we propagate gradients.
#  8. we upgrade parameters with our gradients and use upgraded parameters for another forward pass of this MLP.
#
# At the end we use one of the standards visualization techniques for model evaluation.

# %%
model = tf.keras.Sequential([
  tf.keras.layers.InputLayer(11),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(30, activation="relu"),
  tf.keras.layers.Dense(19, activation="softmax")
])


model.compile(optimizer='adam',
                loss=categorical_crossentropy,
                metrics=["accuracy"])

BATCH_SIZE = 4
EPOCHS = 100
SHUFFLE = True

history = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data = (X_val, y_val), shuffle=SHUFFLE)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 28ms/step - loss: 2.9853 - accuracy: 0.1111 - val_loss: 2.9438 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 5/5 [==============================] - 0s 7ms/step - loss: 2.9577 - accuracy: 0.0000e+00 - val_loss: 2.9440 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9630 - accuracy: 0.0000e+00 - val_loss: 2.9437 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.9445 - accuracy: 0.1111 - val_loss: 2.9435 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9482 - accuracy: 0.0556 - val_loss: 2.9436 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9686 - accuracy: 0.0556 - val_loss: 2.9435 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9686 - accuracy: 0.1111 - val_loss: 2.9430 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9336 - accuracy: 0.0556 - val_loss: 2.9418 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9308 - accuracy: 0.1667 - val_loss: 2.9409 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9310 - accuracy: 0.1111 - val_loss: 2.9400 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9528 - accuracy: 0.0000e+00 - val_loss: 2.9394 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9248 - accuracy: 0.0000e+00 - val_loss: 2.9388 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9444 - accuracy: 0.0556 - val_loss: 2.9384 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9338 - accuracy: 0.1667 - val_loss: 2.9373 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9086 - accuracy: 0.0556 - val_loss: 2.9365 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9045 - accuracy: 0.0556 - val_loss: 2.9352 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9162 - accuracy: 0.0556 - val_loss: 2.9340 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9308 - accuracy: 0.0556 - val_loss: 2.9334 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.8901 - accuracy: 0.1111 - val_loss: 2.9333 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.8936 - accuracy: 0.0556 - val_loss: 2.9334 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8662 - accuracy: 0.1111 - val_loss: 2.9333 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8774 - accuracy: 0.1111 - val_loss: 2.9329 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.8612 - accuracy: 0.0556 - val_loss: 2.9325 - val_accuracy: 0.1429
# Epoch 24/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9144 - accuracy: 0.0556 - val_loss: 2.9318 - val_accuracy: 0.1429
# Epoch 25/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8723 - accuracy: 0.0556 - val_loss: 2.9316 - val_accuracy: 0.1429
# Epoch 26/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9171 - accuracy: 0.0000e+00 - val_loss: 2.9315 - val_accuracy: 0.1429
# Epoch 27/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8940 - accuracy: 0.0556 - val_loss: 2.9312 - val_accuracy: 0.1429
# Epoch 28/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.9154 - accuracy: 0.0556 - val_loss: 2.9301 - val_accuracy: 0.1429
# Epoch 29/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8678 - accuracy: 0.0556 - val_loss: 2.9297 - val_accuracy: 0.1429
# Epoch 30/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8195 - accuracy: 0.0556 - val_loss: 2.9291 - val_accuracy: 0.1429
# Epoch 31/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8890 - accuracy: 0.0556 - val_loss: 2.9283 - val_accuracy: 0.1429
# Epoch 32/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8772 - accuracy: 0.1111 - val_loss: 2.9275 - val_accuracy: 0.1429
# Epoch 33/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8099 - accuracy: 0.1667 - val_loss: 2.9271 - val_accuracy: 0.1429
# Epoch 34/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.8088 - accuracy: 0.0556 - val_loss: 2.9268 - val_accuracy: 0.1429
# Epoch 35/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8813 - accuracy: 0.0556 - val_loss: 2.9260 - val_accuracy: 0.1429
# Epoch 36/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8380 - accuracy: 0.1111 - val_loss: 2.9260 - val_accuracy: 0.1429
# Epoch 37/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8402 - accuracy: 0.1111 - val_loss: 2.9254 - val_accuracy: 0.1429
# Epoch 38/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8794 - accuracy: 0.0556 - val_loss: 2.9258 - val_accuracy: 0.1429
# Epoch 39/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7991 - accuracy: 0.0556 - val_loss: 2.9254 - val_accuracy: 0.1429
# Epoch 40/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8009 - accuracy: 0.0556 - val_loss: 2.9250 - val_accuracy: 0.1429
# Epoch 41/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8280 - accuracy: 0.1111 - val_loss: 2.9239 - val_accuracy: 0.1429
# Epoch 42/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7990 - accuracy: 0.0556 - val_loss: 2.9235 - val_accuracy: 0.1429
# Epoch 43/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8153 - accuracy: 0.1111 - val_loss: 2.9230 - val_accuracy: 0.1429
# Epoch 44/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7843 - accuracy: 0.0556 - val_loss: 2.9231 - val_accuracy: 0.1429
# Epoch 45/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8477 - accuracy: 0.1111 - val_loss: 2.9235 - val_accuracy: 0.1429
# Epoch 46/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7877 - accuracy: 0.0556 - val_loss: 2.9235 - val_accuracy: 0.1429
# Epoch 47/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7838 - accuracy: 0.1111 - val_loss: 2.9234 - val_accuracy: 0.1429
# Epoch 48/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7602 - accuracy: 0.1667 - val_loss: 2.9226 - val_accuracy: 0.1429
# Epoch 49/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7561 - accuracy: 0.0556 - val_loss: 2.9222 - val_accuracy: 0.1429
# Epoch 50/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8655 - accuracy: 0.0556 - val_loss: 2.9223 - val_accuracy: 0.1429
# Epoch 51/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8210 - accuracy: 0.1111 - val_loss: 2.9220 - val_accuracy: 0.1429
# Epoch 52/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8301 - accuracy: 0.1667 - val_loss: 2.9220 - val_accuracy: 0.1429
# Epoch 53/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8070 - accuracy: 0.1111 - val_loss: 2.9216 - val_accuracy: 0.1429
# Epoch 54/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7629 - accuracy: 0.0556 - val_loss: 2.9213 - val_accuracy: 0.1429
# Epoch 55/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.7983 - accuracy: 0.1111 - val_loss: 2.9213 - val_accuracy: 0.1429
# Epoch 56/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7750 - accuracy: 0.1111 - val_loss: 2.9210 - val_accuracy: 0.1429
# Epoch 57/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7583 - accuracy: 0.1111 - val_loss: 2.9203 - val_accuracy: 0.1429
# Epoch 58/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8091 - accuracy: 0.1667 - val_loss: 2.9193 - val_accuracy: 0.1429
# Epoch 59/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8375 - accuracy: 0.1111 - val_loss: 2.9193 - val_accuracy: 0.1429
# Epoch 60/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.7786 - accuracy: 0.0556 - val_loss: 2.9192 - val_accuracy: 0.1429
# Epoch 61/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.7978 - accuracy: 0.1667 - val_loss: 2.9195 - val_accuracy: 0.1429
# Epoch 62/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7689 - accuracy: 0.0556 - val_loss: 2.9194 - val_accuracy: 0.1429
# Epoch 63/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7438 - accuracy: 0.1111 - val_loss: 2.9194 - val_accuracy: 0.1429
# Epoch 64/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.7586 - accuracy: 0.1111 - val_loss: 2.9192 - val_accuracy: 0.1429
# Epoch 65/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7666 - accuracy: 0.0556 - val_loss: 2.9190 - val_accuracy: 0.1429
# Epoch 66/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7683 - accuracy: 0.1111 - val_loss: 2.9191 - val_accuracy: 0.1429
# Epoch 67/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7414 - accuracy: 0.1111 - val_loss: 2.9194 - val_accuracy: 0.1429
# Epoch 68/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7392 - accuracy: 0.1667 - val_loss: 2.9198 - val_accuracy: 0.1429
# Epoch 69/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7741 - accuracy: 0.0556 - val_loss: 2.9199 - val_accuracy: 0.1429
# Epoch 70/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7183 - accuracy: 0.1667 - val_loss: 2.9201 - val_accuracy: 0.1429
# Epoch 71/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7369 - accuracy: 0.2222 - val_loss: 2.9206 - val_accuracy: 0.1429
# Epoch 72/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7549 - accuracy: 0.1111 - val_loss: 2.9205 - val_accuracy: 0.1429
# Epoch 73/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7501 - accuracy: 0.1111 - val_loss: 2.9206 - val_accuracy: 0.1429
# Epoch 74/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7476 - accuracy: 0.0556 - val_loss: 2.9204 - val_accuracy: 0.1429
# Epoch 75/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.7452 - accuracy: 0.1111 - val_loss: 2.9211 - val_accuracy: 0.1429
# Epoch 76/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7529 - accuracy: 0.1667 - val_loss: 2.9219 - val_accuracy: 0.1429
# Epoch 77/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7608 - accuracy: 0.1111 - val_loss: 2.9230 - val_accuracy: 0.1429
# Epoch 78/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7802 - accuracy: 0.1111 - val_loss: 2.9235 - val_accuracy: 0.1429
# Epoch 79/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7979 - accuracy: 0.0556 - val_loss: 2.9235 - val_accuracy: 0.1429
# Epoch 80/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7687 - accuracy: 0.0556 - val_loss: 2.9241 - val_accuracy: 0.1429
# Epoch 81/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.7315 - accuracy: 0.1111 - val_loss: 2.9248 - val_accuracy: 0.1429
# Epoch 82/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7718 - accuracy: 0.0556 - val_loss: 2.9252 - val_accuracy: 0.1429
# Epoch 83/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7626 - accuracy: 0.0556 - val_loss: 2.9261 - val_accuracy: 0.1429
# Epoch 84/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7442 - accuracy: 0.1667 - val_loss: 2.9268 - val_accuracy: 0.1429
# Epoch 85/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.8047 - accuracy: 0.1111 - val_loss: 2.9274 - val_accuracy: 0.1429
# Epoch 86/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7390 - accuracy: 0.1667 - val_loss: 2.9275 - val_accuracy: 0.1429
# Epoch 87/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7216 - accuracy: 0.1111 - val_loss: 2.9275 - val_accuracy: 0.1429
# Epoch 88/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.7406 - accuracy: 0.1667 - val_loss: 2.9272 - val_accuracy: 0.1429
# Epoch 89/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7415 - accuracy: 0.1667 - val_loss: 2.9267 - val_accuracy: 0.1429
# Epoch 90/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7305 - accuracy: 0.1111 - val_loss: 2.9266 - val_accuracy: 0.1429
# Epoch 91/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7683 - accuracy: 0.0556 - val_loss: 2.9257 - val_accuracy: 0.1429
# Epoch 92/100
# 5/5 [==============================] - 0s 4ms/step - loss: 2.7281 - accuracy: 0.0556 - val_loss: 2.9250 - val_accuracy: 0.1429
# Epoch 93/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7545 - accuracy: 0.0556 - val_loss: 2.9252 - val_accuracy: 0.1429
# Epoch 94/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7340 - accuracy: 0.1667 - val_loss: 2.9255 - val_accuracy: 0.1429
# Epoch 95/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7321 - accuracy: 0.1111 - val_loss: 2.9249 - val_accuracy: 0.1429
# Epoch 96/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7457 - accuracy: 0.1111 - val_loss: 2.9247 - val_accuracy: 0.1429
# Epoch 97/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7808 - accuracy: 0.0556 - val_loss: 2.9229 - val_accuracy: 0.1429
# Epoch 98/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7207 - accuracy: 0.0556 - val_loss: 2.9213 - val_accuracy: 0.1429
# Epoch 99/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7425 - accuracy: 0.1667 - val_loss: 2.9198 - val_accuracy: 0.1429
# Epoch 100/100
# 5/5 [==============================] - 0s 5ms/step - loss: 2.7801 - accuracy: 0.1111 - val_loss: 2.9182 - val_accuracy: 0.1429

# %% [markdown]
# We still have a low accuracy (bias) mostly because we still deal with a very small dataset. Loss here is a value of the cost function (losses for all predictions). Val_loss is a model variance.
#
# Because loss is lower than a validation loss (though still not significantly) our probability prediction model is said to be <u>overfitting</u>. This is why we have employed one of the regularization techniques for neural networks - we've added Dropout layer. Documentation for this approach can be found in the work of Srivastava et al. Dropout - A Simple Way to Prevent Neural Networks from Overfitting which you can find here https://jmlr.org/papers/v15/srivastava14a.html

# %% [markdown]
# **ANN Training Visualization**
#
# Accuracy goes up with epochs which is intended behavior.

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **How do we encode knowledge**
#
# According to https://www.quora.com/How-do-you-calculate-the-number-of-parameters-of-an-MLP-neural-network our ANN has 11*30 + (30*30 + 30*30) + 19*30 + (30 + 30 + 30 + 19) = 2809 learning parameters.
#
# Or using another formula

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 30)                360
#
#  dense_1 (Dense)             (None, 30)                930
#
#  dropout (Dropout)           (None, 30)                0
#
#  dense_2 (Dense)             (None, 30)                930
#
#  dense_3 (Dense)             (None, 19)                589
#
# =================================================================
# Total params: 2,809
# Trainable params: 2,809
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **MultiLayer Perceptron Evaluation**
#
# Now we have to evaluate our classification model. Non-overfitting softmax regression model for us is a model with roughly same accuracy on a training, validation and test dataset. Visualization through the confusion matrix will help us evaluate model performance on these three types of the data sets.
#
# So now we're going to check our classification accuracy on the training dataset. For evaluation we use a confusion matrix. Confusion matrix consists from the ones and zeros because in our case each organizational pattern in our dataset is represented only once. This could be changed by processing other pattern descriptions from other types of sources but always for the same pattern set. Ones are visible at those places where model classified organizational pattern based on its inverse n-gram frequencies.

# %%
def plot_confusion_matrix(labels, pred_labels):

    fig = plt.figure(figsize=(18, 18))
    ax = fig.add_subplot(1, 1, 1)
    cm = metrics.confusion_matrix(labels, pred_labels)
    cm = metrics.ConfusionMatrixDisplay(cm, display_labels=range(18))
    cm.plot(values_format='d', cmap='Blues', ax=ax)
    
train_set_probabilities_for_classes = model.predict(X_train)
# class with a maximum probability is our predicted quality class
train_set_predicted_classes = np.argmax(train_set_probabilities_for_classes, axis = 1)
y_train_class = np.argmax(y_train, axis = 1)
confusion_matrix(y_train_class, train_set_predicted_classes)

plot_confusion_matrix(y_train_class, train_set_predicted_classes)

# %% [markdown]
# **Statistical Model Evaluation**

# %% [markdown]
# HierarchyOfFactories organizational pattern (pattern 10) has been classified to the same category as Deploy Along The Grain organizational pattern is (pattern 15). This is good because they are from the same pattern language "People and Code Pattern Language". One of the rules of neural networks says that inputs from the same class should be represented similarly and should be classified to the same class or category.
#
# HierarchyOfFactories and Deploy Along The Grain organizational patterns are represented with a same set of the layers and neurons.
