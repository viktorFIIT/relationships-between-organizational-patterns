# %% [markdown]
# **Extracting Relations Between Organizational Patterns with Softmax Regression and Multi-layer Perceptron**
#
# This neural network is designed to classify organizational patterns, pattern languages or organizational pattern sequences. Index of a highest probability in a vector you get from a Softmax regression model is a pattern sequence classification which you're searching for. Our task here is to find whether we can calculate probabilities and likelihood of the organizational patterns based on the frequencies of the words with which they have been documented with.
#
# This work is a natural continuation of previous research conducted by Waseeb et al. in 'Extracting Relations Between Organizational Patterns Using Association Mining' which you can find here at the following site: http://www2.fiit.stuba.sk/~vranic/pub/ExtractingRelations.pdf.
#
# Dataset we're working with is quite similar to the one published on page 4 in Table 1 entitled as "A matrix sample values for n-gram existence against org. patterns". Difference is that we use TF-IDF frequencies instead of the binary-encoded attributes.
#
# Sample dataset with frequencies of 11 bigrams extracted from textual descriptions of the organizational patterns from http://www.orgpatterns.com/ had been provided in Excel sheet as training set. Validation and test set consist of another previously unseen 7 organizational patterns.
#
# <u>Model output example</u>:
#
# Training dataset consists of frequencies of the bigrams for 18 organizational patterns. Output from this Artificial Neural Network is a vector for a pattern with frequencies from a validation and test dataset with as many components as there are patterns in a training dataset:
#
# for a $pattern_{i}$ = (x1, x2, x3, x4, x5, x6, x7, x8, x9, x10, x11, x12, x13, x14, x15, x16, x17, x18),
#
# where $x_{i}$ is output from a softmax regression and it's a likelihood of this pattern given observed frequencies for n-gram.
# Biggest value or highest probability from this vector is a classification of the set of the n-gram inverse frequencies of a given organizational pattern.
#
# **Main Idea of our Approach**
#
# ![table.drawio-2.png](attachment:table.drawio-2.png)
#
# Validation dataset should be used to optimalize hyperparameters (parameters which are not trained during computation of this ANN) and test dataset shall be used only once.
#
# Please note that prediction is correct if it is consistent with an actual class. Accuracy of the model is one of the metrics used to evaluate this behavior.
#
# Theory behind this can be found in a book Dive into Deep Learning: https://d2l.ai/chapter_linear-networks/softmax-regression.html

# %%
import tensorflow as tf
# keras is facade for tensorflow so we don't have to deal with low-level API
from tensorflow import keras 
from tensorflow.keras.models import Sequential # composite pattern for building neural network
from tensorflow.keras.layers import Dense # input, hidden and output layer
from tensorflow.keras.losses import categorical_crossentropy # loss function
from keras.utils.np_utils import to_categorical # hot-encoding for softmax regression
from tensorflow.keras.optimizers import Adam # optimalizer for neural network

# library for data preprocessing and model evaluation
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

import numpy as np # to handle data compactly
import pandas as pd
import matplotlib.pyplot as plt # plotting library

tf.keras.backend.clear_session()

train_df = pd.read_excel('bigram-pattern-frequencies/for-mlp/bigram-pattern-frequencies-train.xlsx', engine='openpyxl')
val_df = pd.read_excel('bigram-pattern-frequencies/for-mlp/bigram-pattern-frequencies-val.xlsx', engine='openpyxl')
test_df = pd.read_excel('bigram-pattern-frequencies/for-mlp/bigram-pattern-frequencies-test.xlsx', engine='openpyxl')

# %% [markdown]
# **Normalization of organizational patterns bigram frequencies**
#
# Why? Because some of the bigrams (independent variables, attributes X) have higher frequencies than the others. This means they are used more in organizational pattern descriptions than those which are used less. We will normalize these attributes so they contribute equally to the model training process. Normalization is often a must-be to in order to get acceptable results from a machine learning or deep learning models.
#
# Because some of the bigrams are used more often than the others they differ in a (statistical) variance. This means they must be normalized because of this fact too. It's not very good to increase learning rate (as one of the hyperparameters of this neural network) when attributes are not normalized before. This could lead to divergency, when we wouldn't be able to find best parameters in our training process.
#
# Good news is we don't have to weigth our labels (indexes representing organizational patterns) since each class (organizational pattern) is represented only once in our working dataset.

# %%
number_of_patterns = 19

train_scaler = StandardScaler()
train_without_target = train_df.drop(['PatternIndex'], axis=1)
train_without_pattern_name = train_without_target.drop(['OrganizationalPattern'], axis=1)
train_features = train_scaler.fit(train_without_pattern_name.values)

X_train = pd.DataFrame(train_scaler.transform(train_df.iloc[:, 1:-1].values))
y_train = to_categorical(train_df.iloc[:,-1].values, number_of_patterns) # hot-encoding label (pattern index) for softmax regression

val_scaler = StandardScaler()
val_without_target = val_df.drop(['PatternIndex'], axis=1)
val_without_pattern_name = val_without_target.drop(['OrganizationalPattern'], axis=1)
val_features = val_scaler.fit(val_without_pattern_name.values)

X_val = pd.DataFrame(val_scaler.transform(val_df.iloc[:, 1:-1].values))
y_val = to_categorical(val_df.iloc[:,-1].values, number_of_patterns)

test_scaler = StandardScaler()
test_without_target = test_df.drop(['PatternIndex'], axis=1)
test_without_pattern_name = test_without_target.drop(['OrganizationalPattern'], axis=1)
test_features = test_scaler.fit(test_without_pattern_name.values)

X_test = pd.DataFrame(test_scaler.transform(test_df.iloc[:, 1:-1].values))
y_test = to_categorical(test_df.iloc[:,-1].values, number_of_patterns)

# %% [markdown]
# **Softmax Regression - Classification of the patterns based on the n-gram frequencies**
#
# Activation functions are those components in neural network which are responsible to generate output from a network. Combination of linear functions (layers of the ANN without these functions perform affine transformations only) is stil a linear function. That's why we need non-linear activation function. Non-linear activation functions help us to take advantage of the GPU processing capabilities.
#
# We must use non-linear activation functions because if we try to visualize frequencies of the n-grams in 2D space we would not be able to separate these data with linear function / line.
#
# ReLU is one of the standard activation functions used in the neural networks. Softmax is activation function too. Number passed as argument to the constructor of the layer of our Artificial Neural Network is number of perceptrons on this layer. Dropout layer is used as regularization technique to eliminate overfitting of the model on training dataset.
#
# First dense layer is our input layer, or layer to consume our dataset. It has 11 neurons, because we have 11 bigrams in our training dataset. Last layer is output layer of this neural network. All layers between are hidden layers of this network. All layers are fully connected layers of this Multi-layer perceptron.
#
# What we're doing here? Well, we go through these steps for 100 epochs:
#
#  1. we pass here our dataset
#  2. we declare ANN as MLP. See https://d2l.ai/chapter_multilayer-perceptrons/index.html
#  3. we declare optimizer which we want to use. It's Adam, best in class: https://arxiv.org/pdf/1412.6980.pdf
#  4. we work with-minibatches. We optimize model parameters passing each 4 rows in our dataset.
#  5. we perform forward pass through this network. This means we generate predictions.
#  6. we compute loss of the prediction
#  7. we propagate back this loss through all the layers of ANN. In fact we propagate gradients.
#  8. then we use these parameters for another forward pass of this MLP.
#
# At the end we use one of the standards visualization techniques for model evaluation.

# %%
NUMBER_OF_TF_IDF_FEATURES = 11

# default weight initializer is glorot_uniform
ann = tf.keras.Sequential([
  tf.keras.layers.InputLayer(NUMBER_OF_TF_IDF_FEATURES),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),  # number of neurons in layer is usually exponent of 2w
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dropout(0.35),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dense(19, activation=tf.nn.softmax)
])

ann.compile(optimizer='adam',
                loss=categorical_crossentropy,
                metrics=["accuracy"])

ann.summary() # architecture of this artificial neural network
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_36 (Dense)            (None, 512)               6144
#
#  batch_normalization_26 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_37 (Dense)            (None, 512)               262656
#
#  batch_normalization_27 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_38 (Dense)            (None, 512)               262656
#
#  batch_normalization_28 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_39 (Dense)            (None, 512)               262656
#
#  batch_normalization_29 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_40 (Dense)            (None, 19)                9747
#
# =================================================================
# Total params: 812,051
# Trainable params: 807,955
# Non-trainable params: 4,096
# _________________________________________________________________

# %%
BATCH_SIZE = 7
EPOCHS = 200
SHUFFLE = True

history = ann.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_data = (X_val, y_val), shuffle=SHUFFLE)
# Out:
# Epoch 1/200
# 3/3 [==============================] - 1s 127ms/step - loss: 3.7744 - accuracy: 0.0556 - val_loss: 2.9314 - val_accuracy: 0.1111
# Epoch 2/200
# 3/3 [==============================] - 0s 32ms/step - loss: 3.3977 - accuracy: 0.0556 - val_loss: 2.9080 - val_accuracy: 0.1111
# Epoch 3/200
# 3/3 [==============================] - 0s 33ms/step - loss: 3.1453 - accuracy: 0.1111 - val_loss: 2.8948 - val_accuracy: 0.1111
# Epoch 4/200
# 3/3 [==============================] - 0s 32ms/step - loss: 3.2613 - accuracy: 0.0556 - val_loss: 2.8768 - val_accuracy: 0.1111
# Epoch 5/200
# 3/3 [==============================] - 0s 34ms/step - loss: 2.6717 - accuracy: 0.2222 - val_loss: 2.8661 - val_accuracy: 0.1111
# Epoch 6/200
# 3/3 [==============================] - 0s 31ms/step - loss: 2.6594 - accuracy: 0.1667 - val_loss: 2.8534 - val_accuracy: 0.1111
# Epoch 7/200
# 3/3 [==============================] - 0s 34ms/step - loss: 2.9519 - accuracy: 0.1111 - val_loss: 2.8496 - val_accuracy: 0.1111
# Epoch 8/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.4771 - accuracy: 0.2222 - val_loss: 2.8419 - val_accuracy: 0.1111
# Epoch 9/200
# 3/3 [==============================] - 0s 33ms/step - loss: 2.8880 - accuracy: 0.1667 - val_loss: 2.8296 - val_accuracy: 0.1111
# Epoch 10/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.6732 - accuracy: 0.1667 - val_loss: 2.8126 - val_accuracy: 0.1667
# Epoch 11/200
# 3/3 [==============================] - 0s 34ms/step - loss: 3.0510 - accuracy: 0.1667 - val_loss: 2.8020 - val_accuracy: 0.1667
# Epoch 12/200
# 3/3 [==============================] - 0s 31ms/step - loss: 2.2301 - accuracy: 0.3889 - val_loss: 2.8058 - val_accuracy: 0.1667
# Epoch 13/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.6565 - accuracy: 0.1667 - val_loss: 2.8124 - val_accuracy: 0.1111
# Epoch 14/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.1059 - accuracy: 0.2222 - val_loss: 2.8161 - val_accuracy: 0.1111
# Epoch 15/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.8274 - accuracy: 0.1667 - val_loss: 2.8248 - val_accuracy: 0.1111
# Epoch 16/200
# 3/3 [==============================] - 0s 29ms/step - loss: 2.6662 - accuracy: 0.1667 - val_loss: 2.8255 - val_accuracy: 0.1111
# Epoch 17/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.4773 - accuracy: 0.1667 - val_loss: 2.8166 - val_accuracy: 0.1667
# Epoch 18/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.4822 - accuracy: 0.2778 - val_loss: 2.8071 - val_accuracy: 0.1667
# Epoch 19/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.7952 - accuracy: 0.1111 - val_loss: 2.7974 - val_accuracy: 0.1667
# Epoch 20/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.3955 - accuracy: 0.1111 - val_loss: 2.7959 - val_accuracy: 0.1667
# Epoch 21/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.4387 - accuracy: 0.2222 - val_loss: 2.8016 - val_accuracy: 0.1667
# Epoch 22/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.7262 - accuracy: 0.1111 - val_loss: 2.8112 - val_accuracy: 0.1667
# Epoch 23/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.3424 - accuracy: 0.1667 - val_loss: 2.8167 - val_accuracy: 0.1111
# Epoch 24/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.5318 - accuracy: 0.1667 - val_loss: 2.8171 - val_accuracy: 0.1111
# Epoch 25/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.4042 - accuracy: 0.2778 - val_loss: 2.8256 - val_accuracy: 0.1111
# Epoch 26/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.9493 - accuracy: 0.1111 - val_loss: 2.8236 - val_accuracy: 0.1111
# Epoch 27/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.5145 - accuracy: 0.1667 - val_loss: 2.8178 - val_accuracy: 0.1111
# Epoch 28/200
# 3/3 [==============================] - 0s 24ms/step - loss: 3.0222 - accuracy: 0.2778 - val_loss: 2.7988 - val_accuracy: 0.1667
# Epoch 29/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.4073 - accuracy: 0.1111 - val_loss: 2.7877 - val_accuracy: 0.1667
# Epoch 30/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.6662 - accuracy: 0.2778 - val_loss: 2.7789 - val_accuracy: 0.1667
# Epoch 31/200
# 3/3 [==============================] - 0s 26ms/step - loss: 2.6376 - accuracy: 0.1667 - val_loss: 2.7820 - val_accuracy: 0.1667
# Epoch 32/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.7387 - accuracy: 0.1111 - val_loss: 2.7801 - val_accuracy: 0.1667
# Epoch 33/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.5161 - accuracy: 0.2222 - val_loss: 2.7807 - val_accuracy: 0.1111
# Epoch 34/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.5273 - accuracy: 0.1667 - val_loss: 2.7888 - val_accuracy: 0.1667
# Epoch 35/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.5892 - accuracy: 0.2222 - val_loss: 2.8001 - val_accuracy: 0.1667
# Epoch 36/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.6231 - accuracy: 0.1667 - val_loss: 2.8125 - val_accuracy: 0.1111
# Epoch 37/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.8840 - accuracy: 0.2222 - val_loss: 2.8274 - val_accuracy: 0.1111
# Epoch 38/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.3016 - accuracy: 0.2778 - val_loss: 2.8461 - val_accuracy: 0.1111
# Epoch 39/200
# 3/3 [==============================] - 0s 27ms/step - loss: 2.3548 - accuracy: 0.2778 - val_loss: 2.8534 - val_accuracy: 0.1111
# Epoch 40/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.7606 - accuracy: 0.1667 - val_loss: 2.8534 - val_accuracy: 0.1111
# Epoch 41/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.5524 - accuracy: 0.2222 - val_loss: 2.8577 - val_accuracy: 0.1111
# Epoch 42/200
# 3/3 [==============================] - 0s 23ms/step - loss: 2.6125 - accuracy: 0.1667 - val_loss: 2.8625 - val_accuracy: 0.1111
# Epoch 43/200
# 3/3 [==============================] - 0s 23ms/step - loss: 2.3482 - accuracy: 0.1667 - val_loss: 2.8704 - val_accuracy: 0.1111
# Epoch 44/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.3276 - accuracy: 0.1667 - val_loss: 2.8841 - val_accuracy: 0.1111
# Epoch 45/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1373 - accuracy: 0.2222 - val_loss: 2.8762 - val_accuracy: 0.1111
# Epoch 46/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.2494 - accuracy: 0.1667 - val_loss: 2.8738 - val_accuracy: 0.1111
# Epoch 47/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.4097 - accuracy: 0.2778 - val_loss: 2.8722 - val_accuracy: 0.1111
# Epoch 48/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.3779 - accuracy: 0.1667 - val_loss: 2.8688 - val_accuracy: 0.1111
# Epoch 49/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.0671 - accuracy: 0.2222 - val_loss: 2.8590 - val_accuracy: 0.1111
# Epoch 50/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.3899 - accuracy: 0.2222 - val_loss: 2.8623 - val_accuracy: 0.1111
# Epoch 51/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.7068 - accuracy: 0.1111 - val_loss: 2.8765 - val_accuracy: 0.1111
# Epoch 52/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.6419 - accuracy: 0.0556 - val_loss: 2.9103 - val_accuracy: 0.1111
# Epoch 53/200
# 3/3 [==============================] - 0s 37ms/step - loss: 2.8343 - accuracy: 0.1667 - val_loss: 2.9164 - val_accuracy: 0.1111
# Epoch 54/200
# 3/3 [==============================] - 0s 35ms/step - loss: 2.1938 - accuracy: 0.1667 - val_loss: 2.9190 - val_accuracy: 0.1111
# Epoch 55/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.5889 - accuracy: 0.2222 - val_loss: 2.9214 - val_accuracy: 0.1111
# Epoch 56/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.2117 - accuracy: 0.1111 - val_loss: 2.9083 - val_accuracy: 0.1111
# Epoch 57/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.2741 - accuracy: 0.3333 - val_loss: 2.9049 - val_accuracy: 0.1667
# Epoch 58/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.5640 - accuracy: 0.1111 - val_loss: 2.9025 - val_accuracy: 0.1667
# Epoch 59/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.4017 - accuracy: 0.1111 - val_loss: 2.9093 - val_accuracy: 0.1111
# Epoch 60/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.2647 - accuracy: 0.2222 - val_loss: 2.9312 - val_accuracy: 0.1111
# Epoch 61/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.8327 - accuracy: 0.2778 - val_loss: 2.9638 - val_accuracy: 0.1111
# Epoch 62/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1994 - accuracy: 0.1111 - val_loss: 2.9512 - val_accuracy: 0.1111
# Epoch 63/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.0394 - accuracy: 0.2222 - val_loss: 2.9513 - val_accuracy: 0.1111
# Epoch 64/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.5918 - accuracy: 0.1111 - val_loss: 2.9412 - val_accuracy: 0.1111
# Epoch 65/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.7594 - accuracy: 0.2222 - val_loss: 2.9426 - val_accuracy: 0.1111
# Epoch 66/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1062 - accuracy: 0.2222 - val_loss: 2.9356 - val_accuracy: 0.1111
# Epoch 67/200
# 3/3 [==============================] - 0s 23ms/step - loss: 2.3968 - accuracy: 0.1667 - val_loss: 2.9108 - val_accuracy: 0.1111
# Epoch 68/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.3804 - accuracy: 0.0556 - val_loss: 2.9122 - val_accuracy: 0.1111
# Epoch 69/200
# 3/3 [==============================] - 0s 24ms/step - loss: 3.0407 - accuracy: 0.1667 - val_loss: 2.9255 - val_accuracy: 0.1667
# Epoch 70/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.2308 - accuracy: 0.1111 - val_loss: 2.9254 - val_accuracy: 0.1667
# Epoch 71/200
# 3/3 [==============================] - 0s 25ms/step - loss: 2.2938 - accuracy: 0.1667 - val_loss: 2.9297 - val_accuracy: 0.1111
# Epoch 72/200
# 3/3 [==============================] - 0s 24ms/step - loss: 1.9686 - accuracy: 0.2778 - val_loss: 2.9302 - val_accuracy: 0.1111
# Epoch 73/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1855 - accuracy: 0.2222 - val_loss: 2.9310 - val_accuracy: 0.1111
# Epoch 74/200
# 3/3 [==============================] - 0s 33ms/step - loss: 1.9169 - accuracy: 0.2778 - val_loss: 2.9346 - val_accuracy: 0.0556
# Epoch 75/200
# 3/3 [==============================] - 0s 27ms/step - loss: 2.4160 - accuracy: 0.1111 - val_loss: 2.9544 - val_accuracy: 0.1111
# Epoch 76/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.1351 - accuracy: 0.1111 - val_loss: 2.9667 - val_accuracy: 0.1111
# Epoch 77/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.0841 - accuracy: 0.1667 - val_loss: 2.9653 - val_accuracy: 0.1111
# Epoch 78/200
# 3/3 [==============================] - 0s 25ms/step - loss: 2.4931 - accuracy: 0.1667 - val_loss: 2.9907 - val_accuracy: 0.1111
# Epoch 79/200
# 3/3 [==============================] - 0s 21ms/step - loss: 2.0901 - accuracy: 0.2778 - val_loss: 2.9953 - val_accuracy: 0.1111
# Epoch 80/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1957 - accuracy: 0.2222 - val_loss: 3.0171 - val_accuracy: 0.0556
# Epoch 81/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.2785 - accuracy: 0.1667 - val_loss: 3.0108 - val_accuracy: 0.0556
# Epoch 82/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.0682 - accuracy: 0.1667 - val_loss: 3.0120 - val_accuracy: 0.0556
# Epoch 83/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.4733 - accuracy: 0.1667 - val_loss: 3.0377 - val_accuracy: 0.1111
# Epoch 84/200
# 3/3 [==============================] - 0s 21ms/step - loss: 2.7034 - accuracy: 0.1111 - val_loss: 3.0831 - val_accuracy: 0.0556
# Epoch 85/200
# 3/3 [==============================] - 0s 21ms/step - loss: 2.4709 - accuracy: 0.1667 - val_loss: 3.1284 - val_accuracy: 0.1111
# Epoch 86/200
# 3/3 [==============================] - 0s 27ms/step - loss: 1.9786 - accuracy: 0.2222 - val_loss: 3.1932 - val_accuracy: 0.0556
# Epoch 87/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.3226 - accuracy: 0.1111 - val_loss: 3.2374 - val_accuracy: 0.0556
# Epoch 88/200
# 3/3 [==============================] - 0s 29ms/step - loss: 2.5570 - accuracy: 0.1667 - val_loss: 3.2377 - val_accuracy: 0.0556
# Epoch 89/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.4795 - accuracy: 0.2778 - val_loss: 3.2194 - val_accuracy: 0.0556
# Epoch 90/200
# 3/3 [==============================] - 0s 31ms/step - loss: 2.1557 - accuracy: 0.2222 - val_loss: 3.2365 - val_accuracy: 0.0556
# Epoch 91/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.1231 - accuracy: 0.2222 - val_loss: 3.2310 - val_accuracy: 0.0556
# Epoch 92/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.2314 - accuracy: 0.2222 - val_loss: 3.1910 - val_accuracy: 0.1111
# Epoch 93/200
# 3/3 [==============================] - 0s 31ms/step - loss: 3.0087 - accuracy: 0.1667 - val_loss: 3.1427 - val_accuracy: 0.1111
# Epoch 94/200
# 3/3 [==============================] - 0s 30ms/step - loss: 2.5713 - accuracy: 0.1111 - val_loss: 3.1351 - val_accuracy: 0.0556
# Epoch 95/200
# 3/3 [==============================] - 0s 21ms/step - loss: 2.1634 - accuracy: 0.2778 - val_loss: 3.1657 - val_accuracy: 0.1111
# Epoch 96/200
# 3/3 [==============================] - 0s 24ms/step - loss: 1.9727 - accuracy: 0.2778 - val_loss: 3.2268 - val_accuracy: 0.0556
# Epoch 97/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.4138 - accuracy: 0.1667 - val_loss: 3.1927 - val_accuracy: 0.0556
# Epoch 98/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.1267 - accuracy: 0.2222 - val_loss: 3.1634 - val_accuracy: 0.0556
# Epoch 99/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.2933 - accuracy: 0.1667 - val_loss: 3.1339 - val_accuracy: 0.0556
# Epoch 100/200
# 3/3 [==============================] - 0s 23ms/step - loss: 2.2167 - accuracy: 0.2222 - val_loss: 3.1529 - val_accuracy: 0.1111
# Epoch 101/200
# 3/3 [==============================] - 0s 19ms/step - loss: 2.2489 - accuracy: 0.1667 - val_loss: 3.1694 - val_accuracy: 0.1111
# Epoch 102/200
# 3/3 [==============================] - 0s 21ms/step - loss: 2.2617 - accuracy: 0.2222 - val_loss: 3.1626 - val_accuracy: 0.0556
# Epoch 103/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.8973 - accuracy: 0.3333 - val_loss: 3.1419 - val_accuracy: 0.0556
# Epoch 104/200
# 3/3 [==============================] - 0s 21ms/step - loss: 2.0663 - accuracy: 0.2778 - val_loss: 3.1409 - val_accuracy: 0.0556
# Epoch 105/200
# 3/3 [==============================] - 0s 21ms/step - loss: 2.5901 - accuracy: 0.1111 - val_loss: 3.1915 - val_accuracy: 0.1111
# Epoch 106/200
# 3/3 [==============================] - 0s 21ms/step - loss: 2.1250 - accuracy: 0.2222 - val_loss: 3.2190 - val_accuracy: 0.1111
# Epoch 107/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.2639 - accuracy: 0.1667 - val_loss: 3.2444 - val_accuracy: 0.1111
# Epoch 108/200
# 3/3 [==============================] - 0s 25ms/step - loss: 2.1820 - accuracy: 0.2222 - val_loss: 3.2539 - val_accuracy: 0.1111
# Epoch 109/200
# 3/3 [==============================] - 0s 23ms/step - loss: 2.3913 - accuracy: 0.1111 - val_loss: 3.2359 - val_accuracy: 0.1111
# Epoch 110/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1862 - accuracy: 0.1111 - val_loss: 3.2663 - val_accuracy: 0.0556
# Epoch 111/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.3315 - accuracy: 0.0556 - val_loss: 3.2668 - val_accuracy: 0.1111
# Epoch 112/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1967 - accuracy: 0.3333 - val_loss: 3.2946 - val_accuracy: 0.1111
# Epoch 113/200
# 3/3 [==============================] - 0s 27ms/step - loss: 2.3608 - accuracy: 0.1111 - val_loss: 3.2884 - val_accuracy: 0.1111
# Epoch 114/200
# 3/3 [==============================] - 0s 23ms/step - loss: 2.4063 - accuracy: 0.2222 - val_loss: 3.2968 - val_accuracy: 0.0556
# Epoch 115/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.2953 - accuracy: 0.1111 - val_loss: 3.3132 - val_accuracy: 0.0556
# Epoch 116/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.2608 - accuracy: 0.1667 - val_loss: 3.3508 - val_accuracy: 0.1111
# Epoch 117/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.1663 - accuracy: 0.1111 - val_loss: 3.4012 - val_accuracy: 0.1111
# Epoch 118/200
# 3/3 [==============================] - 0s 23ms/step - loss: 2.4888 - accuracy: 0.2222 - val_loss: 3.4547 - val_accuracy: 0.1111
# Epoch 119/200
# 3/3 [==============================] - 0s 22ms/step - loss: 1.9846 - accuracy: 0.3333 - val_loss: 3.5271 - val_accuracy: 0.0556
# Epoch 120/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.3369 - accuracy: 0.2222 - val_loss: 3.5633 - val_accuracy: 0.1111
# Epoch 121/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.7453 - accuracy: 0.1667 - val_loss: 3.5318 - val_accuracy: 0.1111
# Epoch 122/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.1000 - accuracy: 0.2222 - val_loss: 3.4615 - val_accuracy: 0.1111
# Epoch 123/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.1468 - accuracy: 0.2222 - val_loss: 3.4025 - val_accuracy: 0.1111
# Epoch 124/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.1367 - accuracy: 0.1667 - val_loss: 3.3737 - val_accuracy: 0.1111
# Epoch 125/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.2681 - accuracy: 0.1667 - val_loss: 3.3534 - val_accuracy: 0.1111
# Epoch 126/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.2977 - accuracy: 0.2222 - val_loss: 3.3957 - val_accuracy: 0.1111
# Epoch 127/200
# 3/3 [==============================] - 0s 29ms/step - loss: 2.3466 - accuracy: 0.1667 - val_loss: 3.3992 - val_accuracy: 0.1111
# Epoch 128/200
# 3/3 [==============================] - 0s 30ms/step - loss: 3.0342 - accuracy: 0.2222 - val_loss: 3.3574 - val_accuracy: 0.1111
# Epoch 129/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.1245 - accuracy: 0.2222 - val_loss: 3.3397 - val_accuracy: 0.0556
# Epoch 130/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.3876 - accuracy: 0.2222 - val_loss: 3.2907 - val_accuracy: 0.1111
# Epoch 131/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.3011 - accuracy: 0.1667 - val_loss: 3.2435 - val_accuracy: 0.1111
# Epoch 132/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1688 - accuracy: 0.1667 - val_loss: 3.2493 - val_accuracy: 0.1111
# Epoch 133/200
# 3/3 [==============================] - 0s 25ms/step - loss: 2.3460 - accuracy: 0.0556 - val_loss: 3.2941 - val_accuracy: 0.0556
# Epoch 134/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.3565 - accuracy: 0.1111 - val_loss: 3.3914 - val_accuracy: 0.1111
# Epoch 135/200
# 3/3 [==============================] - 0s 23ms/step - loss: 2.2532 - accuracy: 0.0000e+00 - val_loss: 3.4974 - val_accuracy: 0.0556
# Epoch 136/200
# 3/3 [==============================] - 0s 25ms/step - loss: 2.1321 - accuracy: 0.2222 - val_loss: 3.5853 - val_accuracy: 0.0556
# Epoch 137/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.3053 - accuracy: 0.1667 - val_loss: 3.6365 - val_accuracy: 0.0556
# Epoch 138/200
# 3/3 [==============================] - 0s 21ms/step - loss: 2.4862 - accuracy: 0.2222 - val_loss: 3.5642 - val_accuracy: 0.0556
# Epoch 139/200
# 3/3 [==============================] - 0s 20ms/step - loss: 1.7978 - accuracy: 0.4444 - val_loss: 3.5256 - val_accuracy: 0.1111
# Epoch 140/200
# 3/3 [==============================] - 0s 20ms/step - loss: 1.9192 - accuracy: 0.2778 - val_loss: 3.4633 - val_accuracy: 0.1111
# Epoch 141/200
# 3/3 [==============================] - 0s 24ms/step - loss: 1.9948 - accuracy: 0.2222 - val_loss: 3.4230 - val_accuracy: 0.1111
# Epoch 142/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.3274 - accuracy: 0.0556 - val_loss: 3.4325 - val_accuracy: 0.1111
# Epoch 143/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.4611 - accuracy: 0.0556 - val_loss: 3.4114 - val_accuracy: 0.1667
# Epoch 144/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.4635 - accuracy: 0.2222 - val_loss: 3.4100 - val_accuracy: 0.1667
# Epoch 145/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.2964 - accuracy: 0.2222 - val_loss: 3.4964 - val_accuracy: 0.0556
# Epoch 146/200
# 3/3 [==============================] - 0s 21ms/step - loss: 2.2353 - accuracy: 0.1667 - val_loss: 3.5730 - val_accuracy: 0.0556
# Epoch 147/200
# 3/3 [==============================] - 0s 21ms/step - loss: 2.2723 - accuracy: 0.2222 - val_loss: 3.5547 - val_accuracy: 0.0556
# Epoch 148/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1132 - accuracy: 0.2222 - val_loss: 3.5306 - val_accuracy: 0.0556
# Epoch 149/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.1764 - accuracy: 0.2222 - val_loss: 3.5015 - val_accuracy: 0.0556
# Epoch 150/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.5105 - accuracy: 0.2222 - val_loss: 3.4438 - val_accuracy: 0.0556
# Epoch 151/200
# 3/3 [==============================] - 0s 19ms/step - loss: 2.0379 - accuracy: 0.3333 - val_loss: 3.4004 - val_accuracy: 0.0556
# Epoch 152/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.4668 - accuracy: 0.2222 - val_loss: 3.3206 - val_accuracy: 0.1111
# Epoch 153/200
# 3/3 [==============================] - 0s 21ms/step - loss: 1.9863 - accuracy: 0.2778 - val_loss: 3.3341 - val_accuracy: 0.1111
# Epoch 154/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.2787 - accuracy: 0.3333 - val_loss: 3.3172 - val_accuracy: 0.1111
# Epoch 155/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1581 - accuracy: 0.2222 - val_loss: 3.3535 - val_accuracy: 0.1111
# Epoch 156/200
# 3/3 [==============================] - 0s 24ms/step - loss: 1.9766 - accuracy: 0.2222 - val_loss: 3.3591 - val_accuracy: 0.1111
# Epoch 157/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.5625 - accuracy: 0.2222 - val_loss: 3.4090 - val_accuracy: 0.1111
# Epoch 158/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.5495 - accuracy: 0.1667 - val_loss: 3.4507 - val_accuracy: 0.1111
# Epoch 159/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.7559 - accuracy: 0.2222 - val_loss: 3.5150 - val_accuracy: 0.1111
# Epoch 160/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.4190 - accuracy: 0.1667 - val_loss: 3.5407 - val_accuracy: 0.1111
# Epoch 161/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.2224 - accuracy: 0.1111 - val_loss: 3.5486 - val_accuracy: 0.0556
# Epoch 162/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.3543 - accuracy: 0.2778 - val_loss: 3.4940 - val_accuracy: 0.0556
# Epoch 163/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.0575 - accuracy: 0.2222 - val_loss: 3.4358 - val_accuracy: 0.0556
# Epoch 164/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.4482 - accuracy: 0.0556 - val_loss: 3.3789 - val_accuracy: 0.1111
# Epoch 165/200
# 3/3 [==============================] - 0s 29ms/step - loss: 2.0931 - accuracy: 0.1667 - val_loss: 3.3718 - val_accuracy: 0.0556
# Epoch 166/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.0599 - accuracy: 0.2778 - val_loss: 3.3794 - val_accuracy: 0.0556
# Epoch 167/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.1924 - accuracy: 0.1667 - val_loss: 3.4383 - val_accuracy: 0.0000e+00
# Epoch 168/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.0377 - accuracy: 0.2778 - val_loss: 3.4745 - val_accuracy: 0.0556
# Epoch 169/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.2095 - accuracy: 0.1667 - val_loss: 3.5289 - val_accuracy: 0.0556
# Epoch 170/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.0478 - accuracy: 0.1667 - val_loss: 3.5744 - val_accuracy: 0.0556
# Epoch 171/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.3815 - accuracy: 0.1667 - val_loss: 3.5339 - val_accuracy: 0.0000e+00
# Epoch 172/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.4168 - accuracy: 0.3333 - val_loss: 3.4156 - val_accuracy: 0.0000e+00
# Epoch 173/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1868 - accuracy: 0.2222 - val_loss: 3.3175 - val_accuracy: 0.1111
# Epoch 174/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.5706 - accuracy: 0.2222 - val_loss: 3.2730 - val_accuracy: 0.1667
# Epoch 175/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.3426 - accuracy: 0.1111 - val_loss: 3.2997 - val_accuracy: 0.0556
# Epoch 176/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.2738 - accuracy: 0.1111 - val_loss: 3.3653 - val_accuracy: 0.1111
# Epoch 177/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.2636 - accuracy: 0.2222 - val_loss: 3.3968 - val_accuracy: 0.1111
# Epoch 178/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.4199 - accuracy: 0.0556 - val_loss: 3.4333 - val_accuracy: 0.1111
# Epoch 179/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1277 - accuracy: 0.2222 - val_loss: 3.4713 - val_accuracy: 0.0556
# Epoch 180/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.3227 - accuracy: 0.1667 - val_loss: 3.5654 - val_accuracy: 0.0556
# Epoch 181/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.5293 - accuracy: 0.2222 - val_loss: 3.5162 - val_accuracy: 0.0556
# Epoch 182/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1533 - accuracy: 0.2778 - val_loss: 3.3897 - val_accuracy: 0.0556
# Epoch 183/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.6538 - accuracy: 0.1111 - val_loss: 3.2357 - val_accuracy: 0.0556
# Epoch 184/200
# 3/3 [==============================] - 0s 28ms/step - loss: 2.5602 - accuracy: 0.1667 - val_loss: 3.1630 - val_accuracy: 0.1111
# Epoch 185/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.2596 - accuracy: 0.2222 - val_loss: 3.2076 - val_accuracy: 0.0556
# Epoch 186/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.7431 - accuracy: 0.2778 - val_loss: 3.2810 - val_accuracy: 0.1111
# Epoch 187/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.0849 - accuracy: 0.2778 - val_loss: 3.2868 - val_accuracy: 0.0556
# Epoch 188/200
# 3/3 [==============================] - 0s 21ms/step - loss: 2.2119 - accuracy: 0.2222 - val_loss: 3.2747 - val_accuracy: 0.0556
# Epoch 189/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.2694 - accuracy: 0.2222 - val_loss: 3.3036 - val_accuracy: 0.0556
# Epoch 190/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.3282 - accuracy: 0.1111 - val_loss: 3.3409 - val_accuracy: 0.1111
# Epoch 191/200
# 3/3 [==============================] - 0s 24ms/step - loss: 1.9687 - accuracy: 0.2778 - val_loss: 3.3116 - val_accuracy: 0.1111
# Epoch 192/200
# 3/3 [==============================] - 0s 20ms/step - loss: 2.1190 - accuracy: 0.1111 - val_loss: 3.2787 - val_accuracy: 0.1111
# Epoch 193/200
# 3/3 [==============================] - 0s 21ms/step - loss: 1.9549 - accuracy: 0.2222 - val_loss: 3.2777 - val_accuracy: 0.1111
# Epoch 194/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.2807 - accuracy: 0.1667 - val_loss: 3.2645 - val_accuracy: 0.1111
# Epoch 195/200
# 3/3 [==============================] - 0s 24ms/step - loss: 2.1103 - accuracy: 0.2222 - val_loss: 3.2097 - val_accuracy: 0.1111
# Epoch 196/200
# 3/3 [==============================] - 0s 28ms/step - loss: 1.9706 - accuracy: 0.2778 - val_loss: 3.2466 - val_accuracy: 0.1111
# Epoch 197/200
# 3/3 [==============================] - 0s 34ms/step - loss: 2.4384 - accuracy: 0.1111 - val_loss: 3.2928 - val_accuracy: 0.1111
# Epoch 198/200
# 3/3 [==============================] - 0s 26ms/step - loss: 2.1450 - accuracy: 0.1667 - val_loss: 3.3585 - val_accuracy: 0.1111
# Epoch 199/200
# 3/3 [==============================] - 0s 32ms/step - loss: 2.3417 - accuracy: 0.1111 - val_loss: 3.3800 - val_accuracy: 0.1111
# Epoch 200/200
# 3/3 [==============================] - 0s 27ms/step - loss: 2.1377 - accuracy: 0.2778 - val_loss: 3.4318 - val_accuracy: 0.1111

# %% [markdown]
# We still have a low accuracy (bias) mostly because we still deal with a very small dataset. Loss here is a value of the cost function (losses for all predictions). Val_loss is a model variance.
#
# Because loss is lower than a validation loss (though still not significantly) our probability prediction model is said to be <u>overfitting</u>. This is why we have employed one of the regularization techniques for neural networks - we've added Dropout layer. Documentation for this approach can be found in the work of Srivastava et al. Dropout - A Simple Way to Prevent Neural Networks from Overfitting which you can find here https://jmlr.org/papers/v15/srivastava14a.html
#
# Below are the parameters or knowledge about the dataset of TF-IDF frequencies of organizational patterns which our artificial neural network has learned

# %%
ann.get_weights()

# %% [markdown]
# **ANN Training Visualization**
#
# Accuracy goes up with epochs which is intended behavior. But model is overfitting on training data which means we should alter it so it better generalizes information found in patterns dataset (but we're not doing that now because we have only 20 % accuracy).

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# **How do we encode knowledge**
#
# According to https://www.quora.com/How-do-you-calculate-the-number-of-parameters-of-an-MLP-neural-network our ANN has 11*30 + (30*30 + 30*30) + 19*30 + (30 + 30 + 30 + 19) = 2809 learning parameters.
#
# Or using another formula

# %%
model.summary()

# %% [markdown]
# **MLP evaluation**
#
# Now we have to evaluate our classification model. Non-overfitting softmax regression model for us is a model with a roughly same accuracy exhibited on a training, validation and test dataset. Visualization through the confusion matrix will help us evaluate model performance on these three types of the data sets.
#
# We're going to check our classification accuracy on the training dataset. For evaluation we use a confusion matrix. Confusion matrix consists from the ones and zeros because in our case each organizational pattern in our dataset is represented only once. This could be changed by processing other pattern descriptions from other types of sources but always for the same pattern set. Ones are visible at those places where model classified organizational pattern based on its inverse bigram frequencies.

# %%
def plot_confusion_matrix(labels, pred_labels):

    fig = plt.figure(figsize=(18, 18))
    ax = fig.add_subplot(1, 1, 1)
    cm = metrics.confusion_matrix(labels, pred_labels)
    cm = metrics.ConfusionMatrixDisplay(cm, display_labels=range(18))
    cm.plot(values_format='d', cmap='Blues', ax=ax)
    
train_set_probabilities_for_classes = ann.predict(X_train)
# class with a maximum probability is our predicted quality class
train_set_predicted_classes = np.argmax(train_set_probabilities_for_classes, axis = 1)
y_train_class = np.argmax(y_train, axis = 1)
confusion_matrix(y_train_class, train_set_predicted_classes)

plot_confusion_matrix(y_train_class, train_set_predicted_classes)
# Out:
# 1/1 [==============================] - 0s 84ms/step

# %% [markdown]
# **Model Evaluation and Conclusion**

# %% [markdown]
# Organization Follows Market has been classified to the same category as Deploy Along The Grain organizational pattern is (pattern 15). This is good because they are from the same pattern language "People and Code Pattern Language". One of the rules of neural networks says that inputs from the same class should be represented similarly and should be classified to the same class or category.
#
# HierarchyOfFactories and Deploy Along The Grain organizational patterns are represented with a same set of the layers and neurons.
